# %% [markdown]
# <h1 style= 'color:red; text-align:center'> Lab2 Python </h1>

# %% [markdown]
# ### No.1 Fill a list of five elements from the user, sort in descending and ascending orders then display the output

# %%
from numpy.ma.core import multiply

input(multiply
)
